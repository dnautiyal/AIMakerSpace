# %% [markdown]
# ## CONNECT TO GITHUB REPO
# To work on a GitHub repository in Colab, you can use the following steps:
#
# Go to the GitHub repository that you want to work on.
# Click on the "Code" button and then click on the "Copy to clipboard" button.
# In Colab, create a new notebook.
# In the first cell of the notebook, paste the following code:

# %%
import os
import io

# Get the path to the current working directory
current_directory = os.getcwd()

# Get the path to the GitHub repository
github_repository_path = os.path.join(current_directory, "github_repository")

# Clone the GitHub repository
os.system("git clone https://github.com/dnautiyal/AIMakerSpace.git " + github_repository_path)
# Out:
# 0

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
# %cd github_repository/LangChain-Concepts-101---Build-Your-Own-RAQA-System-main/LangChain-Concepts-101---Build-Your-Own-RAQA-System-main/
# Out:
# /content/github_repository/LangChain-Concepts-101---Build-Your-Own-RAQA-System-main/LangChain-Concepts-101---Build-Your-Own-RAQA-System-main

# %%
# %ls
# Out:
# aimakerspace/  ai_makerspace.ipynb  data/  images/  README.md  requirements.txt

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Deepak/AI/AIMakerSpace/Week-1/LangChain-Concepts-101---Build-Your-Own-RAQA-System-main/LangChain-Concepts-101---Build-Your-Own-RAQA-System-main'

# %%
# %cd /content/drive/MyDrive/Deepak/AI/AIMakerSpace/Week-1/LangChain-Concepts-101---Build-Your-Own-RAQA-System-main/LangChain-Concepts-101---Build-Your-Own-RAQA-System-main
# Out:
# /content/drive/MyDrive/Deepak/AI/AIMakerSpace/Week-1/LangChain-Concepts-101---Build-Your-Own-RAQA-System-main/LangChain-Concepts-101---Build-Your-Own-RAQA-System-main

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## PUSH THE CHANGES TO GITHUB
# When you are finished working on the repository, you can commit your changes and push them to GitHub. This will commit your changes and push them to GitHub. You can then view your changes on GitHub. To do this, run the following code in a cell:

# %%
# Commit your changes
os.system("git add .")
os.system("git commit -m \"Your commit message\"")

# Push your changes to GitHub
os.system("git push")
